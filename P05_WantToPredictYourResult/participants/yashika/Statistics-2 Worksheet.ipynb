# %% [markdown]
# # Worksheet - 2

# %% [markdown]
# #### __What do one standard deviation means in normal distribution? Explain using code or way you prefer?__

# %%
#Since , standard deviation is the deviation from the mean , there are various standard scores that tells the number of standard deviations from mean.
#one standard deviation means that the number of std dev. from the mean are 1 (on each side)

# %% [markdown]
# #### __Create a normal distribution of mean 100 and standard deviation 20 and another of mean 100 and standard deviation 10 can you state some differences?__

# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
normal1=np.random.normal(100,20,1000)
normal2=np.random.normal(100,10,1000)
print(normal1.mean(),normal1.var(),normal1.std())
print(normal2.mean(),normal2.var(),normal2.std())
# Out:
# 100.04016475002872 399.3645831942225 19.984108266175465
# 100.13775300593048 102.83273655482736 10.140647738425162

# %% [markdown]
# #### __Plot the both curves and observe the difference__ (Good Task)

# %%
plt.figure(figsize=(15,5))
sb.distplot(normal1)
sb.distplot(normal2)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### __Find 3 type of more distributions and explain them here other than normal distribution. Try to plot them it only takes 2 easy lines:__
# import matplotlib.pyplot as plt<br>
# import seaborn as sns
#
#
# plt.figure(figsize=(15,7)) #<================ This line sets the figure size so use it before every figure plotting<br>
# sns.distplot(normal_vals) #<====== this create a plot (kind of histogram) for the values just put whatever variable you have
#
# plug your values in normal_vals and you will have your histogram

# %%
#The different types o distributions are:
#1)Bionomail Distribution:
bion=np.random.binomial(5,0.6,500)
plt.figure(figsize=(10,5))
sb.distplot(bion)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#2)Poissons Distribution
pois=np.random.poisson(50,2000)
plt.figure(figsize=(10,5))
sb.distplot(pois)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#3 )Uniform
uni=np.random.uniform(0,10,200)
plt.figure(figsize=(10,5))
sb.distplot(uni)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
